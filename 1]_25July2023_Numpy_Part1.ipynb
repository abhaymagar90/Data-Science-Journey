# %% [markdown]
# numpy is a mathematical package inside python. It is used for working with arrays.
#
# It also has functions for working in domain of linear algebra, fourier transform, and matrices.

# %%
import numpy as np

# %%
l = [1,2,3,4,5]

# %%
arr = np.array(l)
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# ndarray   ->   n - dimensional array

# %%
arr.ndim
# Out:
# 1

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1 = np.array([[1,2,3], [2,3,4]])
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# this is a 2-dimensional array

# %%
arr1.ndim
# Out:
# 2

# %% [markdown]
# Representing an Array in the form of graph/ co-ordinate system
#
# ![image.png](data:image/png;base64,...)

# %%
mat = np.matrix(l)
mat
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %%
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.asanyarray(mat)
# Out:
# matrix([[1, 2, 3, 4, 5]])

# %% [markdown]
# The np.array() in Python is used to convert a list, tuple, etc. into a Numpy array.
#
# The numpy.asarray()function is used when we want to convert the input to an array. Input can be lists, lists of tuples, tuples, tuples of tuples, tuples of lists and arrays.
#
# In Python, NumPy array and NumPy asarray are used to convert the data into ndarray. If we talk about the major difference that is when we make a NumPy array using np.array, it creates a copy of the object array or the original array and does not reflect any changes made to the original array. Whereas on the other hand, when we try to use NumPy asarray, it would reflect all the changes made to the original array.
#
# Example
# Here we can see that copy of the original object is created which is actually changed and hence it’s not reflected outside. Whereas, in the next part, we can see that no copy of the original object is created and hence it’s reflected outside.

# %%
import numpy as np

a = np.array([ 2, 3, 4, 5, 6])
print("Original array : ",a)

np_array = np.array(a)
a[3] = 0
print("np.array Array : ",np_array)

np_array = np.asarray(a)
a[3] = 0
print("np.asarray Array : ",np_array)
# Out:
# Original array :  [2 3 4 5 6]
# np.array Array :  [2 3 4 5 6]
# np.asarray Array :  [2 3 4 0 6]

# %%
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
np_array = np.array(a)

print(np_array)

a[2] = 888
# Out:
# [  1   2 888   4   5]

# %%
a
# Out:
# array([  1,   2, 888,   4,   5])

# %%
np_array
# Out:
# array([  1,   2, 888,   4,   5])

# %%
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
np_asarray = np.array(a)
np_asarray
# Out:
# array([1, 2, 3, 4, 5])

# %%
a[2] = 888
a
# Out:
# array([  1,   2, 888,   4,   5])

# %%
np_asarray
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = arr
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr[0] = 100
arr
# Out:
# array([100,   2,   3,   4,   5])

# %%
a
# Out:
# array([100,   2,   3,   4,   5])

# %%
a[0] = 200
a
# Out:
# array([200,   2,   3,   4,   5])

# %%
arr
# Out:
# array([200,   2,   3,   4,   5])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ### This is called as shallow copy

# %%
b = np.copy(arr)
b
# Out:
# array([200,   2,   3,   4,   5])

# %%
b[0] = 925
b
# Out:
# array([925,   2,   3,   4,   5])

# %%
arr
# Out:
# array([200,   2,   3,   4,   5])

# %%
a
# Out:
# array([200,   2,   3,   4,   5])

# %% [markdown]
# np.copy() would create a separate array and changes made in b won't be reflected to a and arr. The main reason is that, a and arr are referring a different array with that of which b is referring
#
# ![image.png](data:image/png;base64,...)
#
#
# ### This is called as deep copy

# %% [markdown]
# # Shallow copy: in this case, both the original array and the new array refer to the same memory location.
#
# # Deep Copy: in this case, the new array refers to different memory location than that of the original array

# %%
np.fromfunction( lambda i,j : i == j, (3,3))
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %% [markdown]
# Here (3,3) is shape of array.
#
# i = row
#
# j = columns
#
# if i == j, Then true else false.
# Hence, all diagonal elements are true. 0-0, 1-1, 2-2

# %%
np.fromfunction( lambda i,j : i * j, (3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %%
list(  ( i*i for i in range(5))  )
# Out:
# [0, 1, 4, 9, 16]

# %%
# Doing the above using numpy function

iterable = ( i*i for i in range(5))
np.fromiter( iterable , float )
# Out:
# array([ 0.,  1.,  4.,  9., 16.])

# %%
iterable = ( i*i for i in range(5))
np.fromiter( iterable , int )
# Out:
# array([ 0,  1,  4,  9, 16])

# %%
iterable = ([1,2,3,4,5])
np.fromiter( iterable , int )
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.fromstring("23 46 53", sep = " ")
# Out:
# array([23., 46., 53.])

# %%
np.fromstring("23,45,67", sep = ",")
# Out:
# array([23., 45., 67.])

# %% [markdown]
# sep => Separate By

# %%
arr1
# Out:
# array([[1, 2, 3],
#        [2, 3, 4]])

# %%
arr.ndim
# Out:
# 1

# %%
arr1.ndim
# Out:
# 2

# %%
arr
# Out:
# array([200,   2,   3,   4,   5])

# %%
arr.size
# Out:
# 5

# %%
arr1.size
# Out:
# 6

# %%
arr1.shape
# Out:
# (2, 3)

# %%
arr.shape
# Out:
# (5,)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
np.array([12.4, 34.7, 45.9]).dtype
# Out:
# dtype('float64')
